# %%
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
device = torch.device("cuda")

# %%
class TmpDataset(Dataset):
    # defining values in the constructor
    def __init__(self, 
                 x, 
                 y
                ):
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y.reshape(-1, 1), dtype=torch.float32)
     
    # Getting the data samples
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    
    # Getting data size/length
    def __len__(self):
        return len(self.x)

# Define the neural network architecture with leaky ReLU activation
class OptionPricingModel5(nn.Module):
    def __init__(self, 
                 input_size, 
                 hidden_size, 
                 output_size, 
                 p,
                 leaky_slope=0.01):
        super(OptionPricingModel5, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.leaky_relu1 = nn.LeakyReLU(leaky_slope)
        self.do1 = nn.Dropout(p=p)
        self.layer2 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu2 = nn.LeakyReLU(leaky_slope)
        self.do2 = nn.Dropout(p=p)
        self.layer3 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu3 = nn.LeakyReLU(leaky_slope)
        self.do3 = nn.Dropout(p=p)
        self.layer4 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu4= nn.LeakyReLU(leaky_slope)
        self.do4 = nn.Dropout(p=p)
        self.layer5 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu5= nn.LeakyReLU(leaky_slope)
        self.do5 = nn.Dropout(p=p)
        self.layer6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.leaky_relu1(x)
        x = self.do1(x)
        x = self.layer2(x)
        x = self.leaky_relu2(x)
        x = self.do2(x)
        x = self.layer3(x)
        x = self.leaky_relu3(x)
        x = self.do3(x)
        x = self.layer4(x)
        x = self.leaky_relu4(x)
        x = self.do4(x)
        x = self.layer5(x)
        x = self.leaky_relu5(x)
        x = self.do5(x)
        x = self.layer6(x)
        return x    
    
# Define the neural network architecture with leaky ReLU activation
class OptionPricingModel4(nn.Module):
    def __init__(self, 
                 input_size, 
                 hidden_size, 
                 output_size, 
                 p,
                 leaky_slope=0.01):
        super(OptionPricingModel4, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.leaky_relu1 = nn.LeakyReLU(leaky_slope)
        self.do1 = nn.Dropout(p=p)
        self.layer2 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu2 = nn.LeakyReLU(leaky_slope)
        self.do2 = nn.Dropout(p=p)
        self.layer3 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu3 = nn.LeakyReLU(leaky_slope)
        self.do3 = nn.Dropout(p=p)
        self.layer4 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu4= nn.LeakyReLU(leaky_slope)
        self.do4 = nn.Dropout(p=p)
        self.layer5 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.leaky_relu1(x)
        x = self.do1(x)
        x = self.layer2(x)
        x = self.leaky_relu2(x)
        x = self.do2(x)
        x = self.layer3(x)
        x = self.leaky_relu3(x)
        x = self.do3(x)
        x = self.layer4(x)
        x = self.leaky_relu4(x)
        x = self.do4(x)
        x = self.layer5(x)
        return x    

# Define the neural network architecture with leaky ReLU activation
class OptionPricingModel3(nn.Module):
    def __init__(self, 
                 input_size, 
                 hidden_size, 
                 output_size, 
                 p,
                 leaky_slope=0.01):
        super(OptionPricingModel3, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.leaky_relu1 = nn.LeakyReLU(leaky_slope)
        self.do1 = nn.Dropout(p=p)
        self.layer2 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu2 = nn.LeakyReLU(leaky_slope)
        self.do2 = nn.Dropout(p=p)
        self.layer3 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu3 = nn.LeakyReLU(leaky_slope)
        self.do3 = nn.Dropout(p=p)
        self.layer4 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.leaky_relu1(x)
        x = self.do1(x)
        x = self.layer2(x)
        x = self.leaky_relu2(x)
        x = self.do2(x)
        x = self.layer3(x)
        x = self.leaky_relu3(x)
        x = self.do3(x)
        x = self.layer4(x)
        return x        

# Define the neural network architecture with leaky ReLU activation
class OptionPricingModel2(nn.Module):
    def __init__(self, 
                 input_size, 
                 hidden_size, 
                 output_size, 
                 p,
                 leaky_slope=0.01):
        super(OptionPricingModel2, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.leaky_relu1 = nn.LeakyReLU(leaky_slope)
        self.do1 = nn.Dropout(p=p)
        self.layer2 = nn.Linear(hidden_size, hidden_size)
        self.leaky_relu2= nn.LeakyReLU(leaky_slope)
        self.do2 = nn.Dropout(p=p)
        self.layer3 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.leaky_relu1(x)
        x = self.do1(x)
        x = self.layer2(x)
        x = self.leaky_relu2(x)
        x = self.do2(x)
        x = self.layer3(x)
        return x        

# Define the neural network architecture with leaky ReLU activation
class OptionPricingModel1(nn.Module):
    def __init__(self, 
                 input_size, 
                 hidden_size, 
                 output_size, 
                 p,
                 leaky_slope=0.01):
        super(OptionPricingModel1, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.leaky_relu1 = nn.LeakyReLU(leaky_slope)
        self.do1 = nn.Dropout(p=p)
        self.layer2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.leaky_relu1(x)
        x = self.do1(x)
        x = self.layer2(x)
        return x         

class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.min_loss = 999999
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, loss):
        if loss < self.min_loss:
            self.min_loss = loss
            self.counter = 0
        elif loss > (self.min_loss - self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False    

def train_one_epoch(dataloader, 
                     test_dataloader, 
                     epoch_index, 
                     device,
                     model,
                     optimizer,
                     loss_fn,
                     scheduler):
    running_loss = 0.
    
    running_vloss = 0.
    sum_loss = 0
    # Here, we use enumerate(dataloader) instead of
    # iter(dataloader) so that we can track the batch
    # index and do some intra-epoch reporting
    ##################### TRAINING  ##################################
    model.train(True)
    for i, data in enumerate(dataloader):
        # Every data instance is an input + label pair
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.to(device))

        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels.to(device))
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()
        sum_loss += loss.item()
        if i % 1000 == 999:
            last_loss = running_loss / 1000 # loss per batch
#             print('  batch {} loss: {}'.format(i + 1, last_loss))
            tb_x = epoch_index * len(dataloader) + i + 1
            running_loss = 0.
#     print('sum_loss:',sum_loss, 'i + 1:', i+1)
    avg_loss = sum_loss / (i + 1)
    
    ##################### TEST EVALUATION  ##################################
    model.eval()
    with torch.no_grad():
        for i, vdata in enumerate(test_dataloader):
            vinputs, vlabels = vdata
            voutputs = model(vinputs.to(device))
            vloss = loss_fn(voutputs, vlabels.to(device))
            running_vloss += vloss
#     print('running_vloss:',running_vloss, 'i + 1:', i+1)
    avg_vloss = running_vloss / (i + 1)
    print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
    
    scheduler.step(avg_loss)
    
    return avg_loss, avg_vloss.item()

# %%
train_data = pd.read_csv('training_set.csv')
test_data = pd.read_csv('test_set.csv')
val_data = pd.read_csv('val_set.csv')

# %%
tmp_train = pd.concat([train_data, val_data]).reset_index(drop=True)

# %%
features = ['T', 'r', 'q', 'v0', 'theta', 'kappa', 'sigma', 'rho', 'm']
label = ['option_price']

# %%
te = TmpDataset(x = test_data[features].values,
                 y = test_data[label].values)

# %%
bs = 1024 * 4
data_size = 100000

test_dataloader = DataLoader(te, 
                            batch_size=bs, 
                            shuffle=False)
tmp_tr = tmp_train.sample(data_size).copy()
tr = TmpDataset(x = tmp_tr[features].values,
                y = tmp_tr[label].values)
train_dataloader = DataLoader(tr, 
                              batch_size=bs, 
                              shuffle=True)

# %%
num_epoch = 1500
# Initialize the model, loss function, and optimizer with 4 layers
input_size = 9
hidden_size1 = 40
output_size = 1
leaky_slope = 0.01
initial_lr = 5e-3

log = { 'datasize': [], 
        'training_MAE': [], 
        'test_MAE': [],
        'hidden_size': [],
        'num_layer': [],
        'dropout': [],
                   }

for hidden_size in [20, 40, 60]:
    for do in [0., 0.2]:
        for num_lay, model in enumerate([OptionPricingModel3(input_size, 
                                                               hidden_size, 
                                                               output_size,
                                                               do,
                                                               leaky_slope), 
                                                 OptionPricingModel4(input_size, 
                                                               hidden_size, 
                                                               output_size,
                                                               do,
                                                               leaky_slope),
                                                OptionPricingModel5(input_size, 
                                                               hidden_size, 
                                                               output_size,
                                                               do,
                                                               leaky_slope)]):
            early_stopper = EarlyStopper(patience=50, min_delta=1e-4)

            #Construct training set
            avg_losses = []
            avg_vlosses = []


            model = model.to(device)

            loss_fn = nn.L1Loss()  # You can experiment with other loss functions like nn.MSELoss()
            optimizer = optim.Adam(model.parameters(), lr=initial_lr)
            scheduler = ReduceLROnPlateau(optimizer, mode = 'min', patience=20, min_lr=1e-7, verbose=True)

            for epoch in range(num_epoch):
                print("--------------------  EPOCH:", epoch, " --------------------")
                avg_loss, avg_vloss = train_one_epoch(train_dataloader, 
                                                      test_dataloader, 
                                                      epoch, 
                                                      device,
                                                      model,
                                                      optimizer,
                                                      loss_fn,
                                                      scheduler)
                avg_losses.append(avg_loss)
                avg_vlosses.append(avg_vloss)

                if epoch % 250 == 249:
                    plt.plot(avg_losses, label='training loss')
                    plt.plot(avg_vlosses, label='test loss')
                    plt.legend()
                    plt.grid()
                    plt.show()

                if early_stopper.early_stop(avg_vlosses[-1]):
                    print("----- EARLY STOPPING TRIGGERED -----")
                    break
            log['datasize'].append(data_size)
            log['training_MAE'].append(np.min(avg_losses))
            log['test_MAE'].append(np.min(avg_vlosses))
            log['hidden_size'].append(hidden_size)
            log['num_layer'].append(num_lay + 1)
            log['dropout'].append(do)
            print('datasize:',  log['datasize'][-1])
            print('training_MAE:',  log['training_MAE'][-1])
            print('test_MAE:',  log['test_MAE'][-1])
            print('hidden_size:',  log['hidden_size'][-1])
            print('num_layer:',  log['num_layer'][-1])
            print('dropout:',  log['dropout'][-1])
            print()
            print('----------------------------------------------------')
# Out:
# --------------------  EPOCH: 0  --------------------
# LOSS train 10.734787120819092 valid 5.9769768714904785
# --------------------  EPOCH: 1  --------------------
# LOSS train 4.933020420074463 valid 4.295511722564697
# --------------------  EPOCH: 2  --------------------
# LOSS train 3.939673891067505 valid 3.5913147926330566
# --------------------  EPOCH: 3  --------------------
# LOSS train 3.343828725814819 valid 3.108981132507324
# --------------------  EPOCH: 4  --------------------
# LOSS train 2.889823417663574 valid 2.6677653789520264
# --------------------  EPOCH: 5  --------------------
# LOSS train 2.5240346813201904 valid 2.3928065299987793
# --------------------  EPOCH: 6  --------------------
# LOSS train 0.9093003201484681 valid 0.5469588041305542
# --------------------  EPOCH: 56  --------------------
# LOSS train 0.8868549489974975 valid 0.6294100284576416
# --------------------  EPOCH: 57  --------------------
# LOSS train 0.8860718989372254 valid 0.5738410949707031
# --------------------  EPOCH: 58  --------------------
# LOSS train 0.8773577857017517 valid 0.5486490726470947
# --------------------  EPOCH: 59  --------------------
# LOSS train 0.8879591035842895 valid 0.6115747094154358
# --------------------  EPOCH: 60  --------------------
# LOSS train 0.8732196402549743 valid 0.615847647190094
# --------------------  EPOCH: 61  --------------------
# LOSS train 0.87111248254776 valid 0.57725989818573
# --------------------  EPOCH: 62  --------------------
# LOSS train 0.8746965146064758 valid 0.7180525660514832
# --------------------  EPOCH: 63  --------------------
# LOSS train 0.8741293144226074 valid 0.5910175442695618
# --------------------  EPOCH: 64  --------------------
# LOSS train 0.8687412905693054 valid 0.6314762234687805
# --------------------  EPOCH: 65  --------------------
# LOSS train 0.8707654714584351 valid 0.7385514974594116
# --------------------  EPOCH: 66  --------------------
# LOSS train 0.8729238939285279 valid 0.7037208676338196
# --------------------  EPOCH: 67  --------------------
# LOSS train 0.8651298904418945 valid 0.644104540348053
# --------------------  EPOCH: 68  --------------------
# LOSS train 0.8516364741325378 valid 0.6327587366104126
# --------------------  EPOCH: 69  --------------------
# LOSS train 0.8471319246292114 valid 0.7529494762420654
# --------------------  EPOCH: 70  --------------------
# LOSS train 0.8500949144363403 valid 0.725699245929718
# --------------------  EPOCH: 71  --------------------
# LOSS train 0.8645253610610962 valid 0.6731256246566772
# --------------------  EPOCH: 72  --------------------
# LOSS train 0.8687641644477844 valid 0.6591103672981262
# --------------------  EPOCH: 73  --------------------
# LOSS train 0.8497007822990418 valid 0.6205122470855713
# --------------------  EPOCH: 74  --------------------
# LOSS train 0.8436018538475036 valid 0.762744128704071
# --------------------  EPOCH: 75  --------------------
# LOSS train 0.8329246020317078 valid 0.6765749454498291
# --------------------  EPOCH: 76  --------------------
# LOSS train 0.8353987240791321 valid 0.705355167388916
# --------------------  EPOCH: 77  --------------------
# LOSS train 0.8388339686393738 valid 0.7165164947509766
# --------------------  EPOCH: 78  --------------------
# LOSS train 0.8301376700401306 valid 0.7014532685279846
# --------------------  EPOCH: 79  --------------------
# LOSS train 0.8318127202987671 valid 0.6167449951171875
# --------------------  EPOCH: 80  --------------------
# LOSS train 0.8287157845497132 valid 0.7087088227272034
# --------------------  EPOCH: 81  --------------------
# LOSS train 0.833559398651123 valid 0.6890463829040527
# ----- EARLY STOPPING TRIGGERED -----
# datasize: 100000
# training_MAE: 0.8287157845497132
# test_MAE: 0.42493197321891785
# hidden_size: 60
# num_layer: 3
# dropout: 0.2
#
# ----------------------------------------------------

# %%
tmp_df = pd.DataFrame(log).sort_values(['hidden_size', 'dropout', 'num_layer'])
tmp_df
# Out:
#     datasize  training_MAE  test_MAE  hidden_size  num_layer  dropout
# 0     100000      0.166959  0.167933           20          1      0.0
# 1     100000      0.154824  0.156367           20          2      0.0
# 2     100000      0.153588  0.154567           20          3      0.0
# 3     100000      1.183345  0.722845           20          1      0.2
# 4     100000      1.297557  0.673520           20          2      0.2
# 5     100000      1.264808  0.787920           20          3      0.2
# 6     100000      0.081593  0.082775           40          1      0.0
# 7     100000      0.069375  0.070352           40          2      0.0
# 8     100000      0.054659  0.056383           40          3      0.0
# 9     100000      0.904760  0.445450           40          1      0.2
# 10    100000      0.914158  0.575920           40          2      0.2
# 11    100000      0.982403  0.617389           40          3      0.2
# 12    100000      0.063765  0.065036           60          1      0.0
# 13    100000      0.046614  0.048872           60          2      0.0
# 18    100000      0.050112  0.052377           60          3      0.0
# 15    100000      0.831291  0.371168           60          1      0.2
# 16    100000      0.802489  0.432137           60          2      0.2
# 17    100000      0.828716  0.424932           60          3      0.2

# %% [markdown]
# # during the training loop, I used index to indicate the number of layers (see 2 cells above)

# %%
tmp_df['num_layer'] = tmp_df['num_layer'].apply(lambda x: x+2)
tmp_df
# Out:
#     datasize  training_MAE  test_MAE  hidden_size  num_layer  dropout
# 0     100000      0.166959  0.167933           20          3      0.0
# 1     100000      0.154824  0.156367           20          4      0.0
# 2     100000      0.153588  0.154567           20          5      0.0
# 3     100000      1.183345  0.722845           20          3      0.2
# 4     100000      1.297557  0.673520           20          4      0.2
# 5     100000      1.264808  0.787920           20          5      0.2
# 6     100000      0.081593  0.082775           40          3      0.0
# 7     100000      0.069375  0.070352           40          4      0.0
# 8     100000      0.054659  0.056383           40          5      0.0
# 9     100000      0.904760  0.445450           40          3      0.2
# 10    100000      0.914158  0.575920           40          4      0.2
# 11    100000      0.982403  0.617389           40          5      0.2
# 12    100000      0.063765  0.065036           60          3      0.0
# 13    100000      0.046614  0.048872           60          4      0.0
# 18    100000      0.050112  0.052377           60          5      0.0
# 15    100000      0.831291  0.371168           60          3      0.2
# 16    100000      0.802489  0.432137           60          4      0.2
# 17    100000      0.828716  0.424932           60          5      0.2

# %% [markdown]
# # Results without dropout

# %%
tmp_df[tmp_df['dropout']==0].drop('dropout', axis=1)
# Out:
#     datasize  training_MAE  test_MAE  hidden_size  num_layer
# 0     100000      0.166959  0.167933           20          3
# 1     100000      0.154824  0.156367           20          4
# 2     100000      0.153588  0.154567           20          5
# 6     100000      0.081593  0.082775           40          3
# 7     100000      0.069375  0.070352           40          4
# 8     100000      0.054659  0.056383           40          5
# 12    100000      0.063765  0.065036           60          3
# 13    100000      0.046614  0.048872           60          4
# 18    100000      0.050112  0.052377           60          5

# %% [markdown]
# # Results with dropout (it does not make sense actually as we don't have overfitting during training) => poor performance

# %%
tmp_df[tmp_df['dropout']==0.2].drop('dropout', axis=1)
# Out:
#     datasize  training_MAE  test_MAE  hidden_size  num_layer
# 3     100000      1.183345  0.722845           20          3
# 4     100000      1.297557  0.673520           20          4
# 5     100000      1.264808  0.787920           20          5
# 9     100000      0.904760  0.445450           40          3
# 10    100000      0.914158  0.575920           40          4
# 11    100000      0.982403  0.617389           40          5
# 15    100000      0.831291  0.371168           60          3
# 16    100000      0.802489  0.432137           60          4
# 17    100000      0.828716  0.424932           60          5
